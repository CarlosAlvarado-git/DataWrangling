# %%
import numpy as np
import pandas as pd
heroes_information = pd.read_csv("heroes_information.csv")

# %%
###instalar desde anaconda navigator######
####pandasql
####mysql
####mysql-connector-c
####mysql-connector-python
from pandasql import *

# %%
####para enlistar los documentos en el directorio#####
os.listdir()
# Out:
# ['SQL Competition.ipynb', 'heroes_information.csv', '.ipynb_checkpoints']

# %%
pysqldf = lambda q: sqldf(q,globals())

# %%
query2 = " SELECT * FROM heroes_information limit 10"

# %%
pysqldf(query2)
# Out:
#    id           name  Gender Eye color               Race Hair color  Height  \
# 0   0         A-Bomb    Male    yellow              Human    No Hair   203.0
# 1   1     Abe Sapien    Male      blue      Icthyo Sapien    No Hair   191.0
# 2   2       Abin Sur    Male      blue            Ungaran    No Hair   185.0
# 3   3    Abomination    Male     green  Human / Radiation    No Hair   203.0
# 4   4        Abraxas    Male      blue      Cosmic Entity      Black   -99.0
# 5   5  Absorbing Man    Male      blue              Human    No Hair   193.0
# 6   6    Adam Monroe    Male      blue               None      Blond   -99.0
# 7   7   Adam Strange    Male      blue              Human      Blond   185.0
# 8   8       Agent 13  Female      blue               None      Blond   173.0
# 9   9      Agent Bob    Male     brown              Human      Brown   178.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics       None      good   441.0
# ...

# %%
query1 = """
SELECT *
FROM heroes_information
WHERE Race='Human'
AND Height > 200;

"""

# %%
pysqldf(query1)
# Out:
#      id           name  Gender Eye color   Race Hair color  Height  \
# 0     0         A-Bomb    Male    yellow  Human    No Hair   203.0
# 1    29        Ant-Man    Male      blue  Human      Blond   211.0
# 2    59           Bane    Male      None  Human       None   203.0
# 3   119       Bloodaxe  Female      blue  Human      Brown   218.0
# 4   221    Doctor Doom    Male     brown  Human      Brown   201.0
# 5   373     Juggernaut    Male      blue  Human        Red   287.0
# 6   391        Kingpin    Male      blue  Human    No Hair   201.0
# 7   412         Lizard    Male       red  Human    No Hair   203.0
# 8   476  Mr Incredible    Male      blue  Human      Blond   201.0
# 9   557            Rey  Female     hazel  Human      Brown   297.0
# 10  583       Scorpion    Male     brown  Human      Brown   211.0
# 11  591       She-Hulk  Female     green  Human      Green   201.0
#
#             Publisher Skin color Alignment  Weight
# ...

# %%
query1 = """
SELECT *
FROM heroes_information
WHERE Eye_color = 'yellow';

"""

# %%
pysqldf(query1)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/opt/anaconda3/envs/dw-2022-clase/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File ~/opt/anaconda3/envs/dw-2022-clase/lib/python3.8/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# OperationalError: no such column: Eye_color
#
# ...

# %%
query_1 = """ 
        select name from heroes_information where id = 0;
"""

# %%
pysqldf(query_1)
# Out:
#      name
# 0  A-Bomb

# %%
query_2 = """
    select count(DISTINCT(Publisher)from heroes_information;
    
"""

# %%
pysqldf(query_2)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/opt/anaconda3/envs/dw-2022-clase/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File ~/opt/anaconda3/envs/dw-2022-clase/lib/python3.8/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# OperationalError: near "from": syntax error
#
# ...

# %%
query_3 = """
    select COUNT(*) FROM heroes_information
    WHERE Height > 200;
"""

# %%
pysqldf(query_3)
# Out:
#    COUNT(*)
# 0        59

# %%
query_4 = """ 
    select COUNT(*) FROM heroes_information
    WHERE Height > 200 and Race = 'Human';
"""

# %%
pysqldf(query_4)
# Out:
#    COUNT(*)
# 0        12

# %%
query_5 = """
    SELECT count(*)FROM heroes_information
    where Weight > 200 and 
"""

# %%
query_6 = """
    SELECT count(*) FROM heroes_information
    where `Eye_color` = 'blue' or `Eye colors` = 'red';
"""

# %%
pysqldf(query_6)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/opt/anaconda3/envs/dw-2022-clase/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File ~/opt/anaconda3/envs/dw-2022-clase/lib/python3.8/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# OperationalError: no such column: eye_color
#
# ...

# %%
query_7 = """
    select name FROM heroes_information
    order by Race
    Desc;  
"""

# %%
pysqldf(query_7)
# Out:
#                name
# 0    Solomon Grundy
# 1            Gamora
# 2              Yoda
# 3          Predator
# 4             Alien
# ..              ...
# 729          Wondra
# 730  Wyatt Wingfoot
# 731           X-Man
# 732     Yellow Claw
# 733            Zoom
#
# [734 rows x 1 columns]

# %%
uqery_9 = """
    select gender, count(*) from heroes_information
    group by gender;

"""

# %%
pysqldf(uqery_9)
# Out:
#    Gender  count(*)
# 0    None        29
# 1  Female       200
# 2    Male       505

# %%
query_10 = """
    select publisher, count(*) from heroes_information
    group by publisher
    having count(*) > 15;
    
    
"""

# %%
pysqldf(query_10)
# Out:
#            Publisher  count(*)
# 0          DC Comics       215
# 1  Dark Horse Comics        18
# 2      Marvel Comics       388
# 3       NBC - Heroes        19
